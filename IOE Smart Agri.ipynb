# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-513ef98a-835f-462d-8c57-34b4ad2f7e52" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-513ef98a-835f-462d-8c57-34b4ad2f7e52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving feeds2.csv to feeds2.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['feeds2.csv']))

# %%
df.head()
# Out:
#                   created_at  entry_id  soilmoisture  humidity  temperature
# 0  2021-04-28T15:28:00+05:30         1           197      95.0         32.5
# 1  2021-04-28T15:28:16+05:30         2           197      95.0         32.4
# 2  2021-04-28T15:28:31+05:30         3           197      95.0         32.3
# 3  2021-04-28T15:28:46+05:30         4           197      95.0         32.5
# 4  2021-04-28T15:29:01+05:30         5           197      95.0         32.4

# %%
df.tail()
# Out:
#                      created_at  entry_id  soilmoisture  humidity  temperature
# 2253  2022-04-14T12:51:38+05:30      2254             5      79.0         32.7
# 2254  2022-04-14T12:51:54+05:30      2255             4      80.0         33.0
# 2255  2022-04-14T12:52:09+05:30      2256             8      80.0         33.1
# 2256  2022-04-14T12:52:24+05:30      2257            12      80.0         33.5
# 2257  2022-04-14T12:52:39+05:30      2258            15      80.0         33.2

# %%
df.size
# Out:
# 11290

# %%
df.shape
# Out:
# (2258, 5)

# %%
df.columns
# Out:
# Index(['created_at', 'entry_id', 'soilmoisture', 'humidity', 'temperature'], dtype='object')

# %%
df.dtypes
# Out:
# created_at       object
# entry_id          int64
# soilmoisture      int64
# humidity        float64
# temperature     float64
# dtype: object

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.jointplot(x='soilmoisture',y='humidity',data = df)

# %%
sns.jointplot(x='temperature',y='humidity',data = df)

# %%
sns.jointplot(x='soilmoisture',y='temperature',data = df)

# %%
sns.scatterplot(data=df, x="soilmoisture", y="humidity")

# %%
sns.scatterplot(data=df, x="soilmoisture", y="temperature")

# %%
sns.scatterplot(data=df, x="temperature", y="humidity")

# %%
sns.scatterplot(data=df, x="soilmoisture", y="humidity")
